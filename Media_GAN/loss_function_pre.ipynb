# %%
import numpy as np
import tensorflow as tf

# %% [markdown]
# ## **손실함수**

# %% [markdown]
# **SSE(Sum of Squares for Error) vs. Mean Squared Error(MSE)**

# %% [markdown]
# ### **Loss Function: SSE**

# %% [markdown]
# ![e 4.1.png](data:image/png;base64,...)

# %% [markdown]
# ### **Loss Function: MSE**

# %% [markdown]
# ![img.png](data:image/png;base64,...)

# %% [markdown]
# ### **Loss Function: Cross Entropy Error**

# %% [markdown]
# ![e 4.2.png](data:image/png;base64,...)

# %% [markdown]
# ![e 4.3.png](data:image/png;base64,...)
